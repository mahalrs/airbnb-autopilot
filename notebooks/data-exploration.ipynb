# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ori = pd.read_csv('airbnb-listings.csv',encoding='utf-8',engine='python',sep=';')

# %%
ori2 = ori.loc[ori.Country.isin(['United States','United Kingdom','Canada','Australia'])]
ori2.iloc[:,:20].head()
# Out:
#            ID                            Listing Url       Scrape ID  \
# 241  16163330  https://www.airbnb.com/rooms/16163330  20170510102046
# 242   6846209   https://www.airbnb.com/rooms/6846209  20170510102046
# 243   6448745   https://www.airbnb.com/rooms/6448745  20170510102046
# 244  18139782  https://www.airbnb.com/rooms/18139782  20170510102046
# 245  12467112  https://www.airbnb.com/rooms/12467112  20170510102046
#
#     Last Scraped                                          Name  \
# 241   2017-05-10                   Quiet Space to sleep & rest
# 242   2017-05-10                      Rogue Philanthropy Manor
# 243   2017-05-10          1 Bedroom in Beautiful Humboldt Park
# 244   2017-05-10             Private Entry 2 Bdrm near Transit
# 245   2017-05-10  Beautiful Eco-Friendly Room in Garfield Park
#
#                                                Summary  \
# 241  Hello.  Small bedroom with twin bed, chair, ni...
# 242  Our Humboldt Park home features 1.5 bathrooms ...
# ...

# %%
ori2.iloc[:,20:40].head()
# Out:
#                                        Host URL Host Name  Host Since  \
# 241   https://www.airbnb.com/users/show/3836635   Caitlin  2012-10-11
# 242  https://www.airbnb.com/users/show/35874075    Denise  2015-06-15
# 243  https://www.airbnb.com/users/show/27538050      Jeff  2015-02-10
# 244  https://www.airbnb.com/users/show/22308676     Brodi  2014-10-08
# 245   https://www.airbnb.com/users/show/1284557     David  2011-10-13
#
#                         Host Location  \
# 241  Chicago, Illinois, United States
# 242  Chicago, Illinois, United States
# 243  Chicago, Illinois, United States
# 244  Chicago, Illinois, United States
# 245  Chicago, Illinois, United States
#
#                                             Host About Host Response Time  \
# 241  I am a happy, relaxed individual that enjoys c...     within an hour
# 242  I'm a Chicago transplant via the Quad Cities a...       within a day
# 243                                                NaN     within an hour
# ...

# %%
ori2.iloc[:,40:60].head()
# Out:
#     Zipcode   Market Smart Location Country Code        Country   Latitude  \
# 241   60647  Chicago    Chicago, IL           US  United States  41.911282
# 242   60651  Chicago    Chicago, IL           US  United States  41.906670
# 243   60651  Chicago    Chicago, IL           US  United States  41.905264
# 244   60651  Chicago    Chicago, IL           US  United States  41.896352
# 245   60624  Chicago    Chicago, IL           US  United States  41.887172
#
#      Longitude Property Type        Room Type  Accommodates  Bathrooms  \
# 241 -87.702463     Apartment     Private room           1.0        1.0
# 242 -87.714291         House     Private room           2.0        1.5
# 243 -87.710297     Apartment     Private room           2.0        1.0
# 244 -87.729763     Apartment  Entire home/apt           6.0        1.0
# 245 -87.707650         House     Private room           2.0        1.0
#
#      Bedrooms  Beds  Bed Type  \
# 241       1.0   1.0  Real Bed
# ...

# %%
ori2.iloc[:,60:80].head()
# Out:
#      Cleaning Fee  Guests Included  Extra People  Minimum Nights  \
# 241           7.0              1.0           0.0             3.0
# 242          10.0              2.0          25.0             1.0
# 243           5.0              2.0          15.0             1.0
# 244          15.0              2.0          10.0             1.0
# 245           9.0              1.0          10.0             2.0
#
#      Maximum Nights Calendar Updated Has Availability  Availability 30  \
# 241          1125.0      2 weeks ago              NaN              2.0
# 242          1125.0      5 weeks ago              NaN             30.0
# 243          1125.0            today              NaN              7.0
# 244          1125.0            today              NaN              6.0
# 245          1125.0            today              NaN              9.0
#
#      Availability 60  Availability 90  Availability 365 Calendar last Scraped  \
# ...

# %%
ori2.iloc[:,80:90].head()
# Out:
#      Review Scores Location  Review Scores Value                    License  \
# 241                     9.0                 10.0                        NaN
# 242                     9.0                 10.0  City registration pending
# 243                    10.0                 10.0  City registration pending
# 244                     9.0                 10.0  City registration pending
# 245                     8.0                  9.0  City registration pending
#
#                            Jurisdiction Names Cancellation Policy  \
# 241  Illinois State, Cook County, IL, CHICAGO              strict
# 242  Illinois State, Cook County, IL, CHICAGO            flexible
# 243  Illinois State, Cook County, IL, CHICAGO            moderate
# 244  Illinois State, Cook County, IL, CHICAGO            flexible
# 245  Illinois State, Cook County, IL, CHICAGO              strict
#
#      Calculated host listings count  Reviews per Month  \
# ...

# %%
ori2.describe()
# Out:
#             Host ID  Host Response Rate  Host Listings Count  \
# count  2.670660e+05       203679.000000        266637.000000
# mean   3.198984e+07           93.610780             8.842475
# std    3.140981e+07           17.101591            53.829854
# min    1.900000e+01            0.000000             0.000000
# 25%    6.638417e+06           98.000000             1.000000
# 50%    2.196021e+07          100.000000             1.000000
# 75%    4.775556e+07          100.000000             3.000000
# max    1.331507e+08          100.000000          1114.000000
#
#        Host Total Listings Count       Latitude      Longitude   Accommodates  \
# count              266637.000000  267066.000000  267066.000000  267005.000000
# mean                    8.842475      30.715431     -35.993956       3.286335
# std                    53.829854      28.649498      88.954186       2.195675
# min                     0.000000     -38.224427    -123.218712       1.000000
# ...

# %%
list(zip(ori2.isnull().sum().index,ori2.isnull().sum()))
# Out:
# [('ID', 0),
#  ('Listing Url', 0),
#  ('Scrape ID', 0),
#  ('Last Scraped', 0),
#  ('Name', 55),
#  ('Summary', 7458),
#  ('Space', 79515),
#  ('Description', 83),
#  ('Experiences Offered', 0),
#  ('Neighborhood Overview', 106023),
#  ('Notes', 154631),
#  ('Transit', 99280),
#  ('Access', 117617),
#  ('Interaction', 125108),
#  ('House Rules', 103903),
#  ('Thumbnail Url', 43641),
#  ('Medium Url', 43641),
#  ('Picture Url', 286),
#  ('XL Picture Url', 43641),
#  ('Host ID', 0),
#  ('Host URL', 0),
#  ('Host Name', 429),
#  ('Host Since', 429),
#  ('Host Location', 1376),
#  ('Host About', 102253),
#  ('Host Response Time', 63387),
#  ('Host Response Rate', 63387),
#  ('Host Acceptance Rate', 233593),
#  ('Host Thumbnail Url', 429),
#  ('Host Picture Url', 429),
#  ('Host Neighbourhood', 57941),
#  ('Host Listings Count', 429),
#  ('Host Total Listings Count', 429),
#  ('Host Verifications', 166),
#  ('Street', 0),
#  ('Neighbourhood', 71258),
#  ('Neighbourhood Cleansed', 0),
# ...

# %%
ori2.loc[:,'Experiences Offered'].value_counts()
# Out:
# none        491735
# business      1046
# social         925
# family         824
# romantic       423
# 1                1
# Name: Experiences Offered, dtype: int64

# %%
list(zip(ori2.dtypes.index,ori2.dtypes))
# Out:
# [('ID', dtype('O')),
#  ('Listing Url', dtype('O')),
#  ('Scrape ID', dtype('O')),
#  ('Last Scraped', dtype('O')),
#  ('Name', dtype('O')),
#  ('Summary', dtype('O')),
#  ('Space', dtype('O')),
#  ('Description', dtype('O')),
#  ('Experiences Offered', dtype('O')),
#  ('Neighborhood Overview', dtype('O')),
#  ('Notes', dtype('O')),
#  ('Transit', dtype('O')),
#  ('Access', dtype('O')),
#  ('Interaction', dtype('O')),
#  ('House Rules', dtype('O')),
#  ('Thumbnail Url', dtype('O')),
#  ('Medium Url', dtype('O')),
#  ('Picture Url', dtype('O')),
#  ('XL Picture Url', dtype('O')),
#  ('Host ID', dtype('int64')),
#  ('Host URL', dtype('O')),
#  ('Host Name', dtype('O')),
#  ('Host Since', dtype('O')),
#  ('Host Location', dtype('O')),
#  ('Host About', dtype('O')),
#  ('Host Response Time', dtype('O')),
#  ('Host Response Rate', dtype('float64')),
#  ('Host Acceptance Rate', dtype('O')),
#  ('Host Thumbnail Url', dtype('O')),
#  ('Host Picture Url', dtype('O')),
# ...

# %%
ori2.Country.unique()
# Out:
# array(['United States', 'United Kingdom', 'Australia', 'Canada'],
#       dtype=object)

# %%
sns.boxplot(data=ori2,x='Price',y='Country')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Country'>

# %%
ori2.groupby('Country').Price.describe()
# Out:
#                    count        mean         std   min   25%    50%    75%  \
# Country
# Australia        40219.0  165.077177  142.167599  13.0  75.0  121.0  200.0
# Canada           30692.0  107.010622   89.156506   0.0  54.0   85.0  128.0
# United Kingdom   60966.0   93.020880   79.842147   8.0  42.0   70.0  115.0
# United States   132581.0  156.051199  136.790843   0.0  75.0  113.0  189.0
#
#                   max
# Country
# Australia       999.0
# Canada          999.0
# United Kingdom  999.0
# United States   999.0

# %%
ori2 = ori2.set_index('ID')

# %%
ori2.index.unique()
# Out:
# Index(['16163330', '6846209', '6448745', '18139782', '12467112', '10661438',
#        '12243016', '13621242', '15925916', '14055024',
#        ...
#        '8387546', '3425069', '6120864', '5362696', '17318819', '15214668',
#        '17345857', '16768276', '17317756', '16943997'],
#       dtype='object', name='ID', length=267064)

# %%
# Out:
# 494954
